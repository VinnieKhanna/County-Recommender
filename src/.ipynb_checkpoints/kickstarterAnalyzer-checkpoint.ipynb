# %% [markdown]
# # Kickstarter Analyzer
# By : Nilesh Manivannan, Ruhan Ponnada, Aayush Shah

# %% [markdown]
# ## Data Cleaning

# %%
from dataProcessing import cleanNull

dataSrc1 = 'data/ks-projects-201612.csv'
dataSrc2 = 'data/ks-projects-201801.csv'
data = cleanNull(dataSrc1, dataSrc2)
# Out:
# /var/folders/qy/_r9bqd4x2ts3hnxbhy9zmfhr0000gn/T/ipykernel_99145/1668324652.py:5: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   data = cleanNull(dataSrc1, dataSrc2)
# Null values before cleaning:
# ID                     0
# name                   1
# category               0
# main_category          0
# currency               0
# deadline               0
# goal                   0
# launched               0
# pledged                0
# state                  0
# backers                0
# country                0
# usd pledged         3698
# usd_pledged_real       0
# usd_goal_real          0
# dtype: int64
#
# Null values after cleaning:
# ID                  0
# name                0
# category            0
# main_category       0
# currency            0
# deadline            0
# goal                0
# launched            0
# pledged             0
# state               0
# backers             0
# country             0
# usd pledged         0
# usd_pledged_real    0
# usd_goal_real       0
# dtype: int64

# %% [markdown]
# ### Heat Map

# %%
from dataProcessing import getHeatMap

data, _, _, _, _ = getHeatMap(data)

# %% [markdown]
# ### Oversampling Using SMOTE

# %%
from dataProcessing import oversampling

resX, resY = oversampling(data)
# Out:
# State value counts before using SMOTE :
# failed: 193733
# successful: 131554
# canceled: 38027
# live: 7168
# undefined: 3467
# suspended: 1821
#
# State value counts after using SMOTE :
# failed: 193733
# canceled: 193733
# successful: 193733
# live: 193733
# suspended: 193733
# undefined: 193733

# %% [markdown]
# ### Splitting Data to Train and Test

# %%
from dataProcessing import splitTestTrainData

sTrain, sTest, trainY, testY, _ = splitTestTrainData(resX, resY)
# Out:
# Size of training data : 929918
# Size of testing data : 232480

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### Training and Testing Accuracy

# %%
import os
from decisionTree import dt_TrainAndPred

if os.path.exists("dt_model.pkl"):
  os.remove("dt_model.pkl")
dt_TrainAndPred(sTrain, trainY, sTest, testY)
# Out:
# Training accuracy : 0.98251
# Model test accuracy : 0.86104
# Model test precision : 0.86122
# Model test recall : 0.86104
# Model test f1 : 0.86093

# %% [markdown]
# ### Confusion Matrix

# %%
from confusionMatrix import getConfusionMatrix, getModelPred

dt_predY = getModelPred("dt_model.pkl", sTest=sTest)
getConfusionMatrix(testY, dt_predY)

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Training and Testing Accuracy

# %%
import os
from randomForest import rf_TrainAndPred

if os.path.exists("rf_model.pkl"):
  os.remove("rf_model.pkl")
rf_TrainAndPred(sTrain, trainY, sTest, testY)
# Out:
# Training accuracy : 0.98251
# Model test accuracy : 0.91659
# Model test precision : 0.91545
# Model test recall : 0.91659
# Model test f1 : 0.91586

# %% [markdown]
# ### Confusion Matrix

# %%
from confusionMatrix import getModelPred, getConfusionMatrix

rf_predY = getModelPred("rf_model.pkl", sTest=sTest)
getConfusionMatrix(testY, rf_predY)

# %% [markdown]
# ## KNN

# %% [markdown]
# ### Training and Testing Accuracy

# %%
import os
from knn import knn_TrainAndPred

if os.path.exists("knn_model.pkl"):
  os.remove("knn_model.pkl")
knn_TrainAndPred(sTrain, trainY, sTest, testY)
# Out:
# Training accuracy : 0.97876
# Model test accuracy : 0.73404
# Model test precision : 0.73193
# Model test recall : 0.73404
# Model test f1 : 0.73263

# %% [markdown]
# ### Confusion Matrix

# %%
from confusionMatrix import getConfusionMatrix

knn_predY = getModelPred("knn_model.pkl", sTest=sTest)
getConfusionMatrix(testY, knn_predY)
